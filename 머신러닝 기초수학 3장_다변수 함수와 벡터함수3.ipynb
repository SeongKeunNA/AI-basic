# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

fig=plt.figure(figsize=(7,7))
ax= plt.axes(projection='3d')
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.zaxis.set_tick_params(labelsize=15)
ax.set_xlabel(r'$x$',fontsize=20)
ax.set_ylabel(r'$y$',fontsize=20)
ax.set_zlabel(r'$z$',fontsize=20)

u=np.linspace(0,1,30)
v=np.linspace(0,1,30)
U,V=np.meshgrid(u,v)
X=U
Y=V
Z=(1+U**2)+(V/(1+V**2))

ax.scatter3D(X,Y,Z,marker='.',color='gray')

plt.show()

# %%
import numpy as np
x=5
f= lambda x:x**2
df= lambda x:2*x

print("f(x)={},df(x)={:.3f} at x={}".format(f(x), df(x),x))

print("f(x)={},df(x)={:.3f}at x={}".format(f(x), (f(x+0.01)-f(x))/0.01 ,x))
# Out:
# f(x)=25,df(x)=10.000 at x=5
# f(x)=25,df(x)=10.010at x=5

# %%
import numpy as np

x=5

f= lambda x:np.exp(x)
df=lambda x:np.exp(x)

print("f(x)={}, df(x)={:.3f} at x={}".format(f(x), df(x), x))

print("f(x)={}, df(x)={:.3f} at x={}".format(f(x), (f(x+0.01)-f(x))/0.01 ,x))
# Out:
# f(x)=148.4131591025766, df(x)=148.413 at x=5
# f(x)=148.4131591025766, df(x)=149.158 at x=5
