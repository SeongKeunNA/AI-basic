# %%
import numpy as np
import matplotlib.pyplot as plt

im=plt.imread("old.png")
im.shape
# Out:
# (210, 280, 4)

# %%
plt.show(im)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-eaa3daccbf84> in <module>
# ----> 1 plt.show(im)
#
# ~\anaconda3\envs\noviceml\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     376     """
#     377     _warn_if_gui_out_of_main_thread()
# --> 378     return _backend_mod.show(*args, **kwargs)
#     379
#     380
#
# ~\anaconda3\envs\noviceml\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      47         # only call close('all') if any to close
#      48         # close triggers gc.collect, which can be slow
# ---> 49         if close and Gcf.get_all_fig_managers():
#      50             matplotlib.pyplot.close('all')
#      51
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
